# %% [markdown]
# # 2 — Member A: Complement Naive Bayes
#
# Complement Naive Bayes is an NB variant designed for sparse text classification.
# Word 1–3 grams and character 2–5 grams represent ordinary vocabulary, phrases,
# spelling variation, negation, and Manglish patterns. Alpha and ComplementNB's norm option
# are selected with five-fold training-only cross-validation. Character features use a 0.5
# weight because training-only CV showed that full weight double-counted correlated evidence
# for NB. The fixed real-review test set is evaluated once.

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd().resolve()
if not (PROJECT_ROOT / 'dataset').exists():
    PROJECT_ROOT = PROJECT_ROOT.parent
sys.path.insert(0, str(PROJECT_ROOT))
DATA_DIR = PROJECT_ROOT / 'dataset'
MODEL_DIR = PROJECT_ROOT / 'model'
print('Project root:', PROJECT_ROOT)

import pandas as pd
from project_workflow import train_naive_bayes
# Out:
# Project root: C:\Users\Fnjtnpcl\Documents\Codex\2026-08-16\referenced-chatgpt-conversation-this-is-an\work\nlp_v31\nlp_sentiment_project_final_fixed (1)\project

# %%
result = train_naive_bayes(PROJECT_ROOT)
pd.DataFrame([result])
# Out:
#                     Model  Accuracy  Precision_weighted  Recall_weighted  \
# 0  Complement Naive Bayes  0.811906            0.820758         0.811906
#
#    F1_weighted  F1_macro                           Best_parameter  CV_macro_F1
# 0     0.805971  0.805971  alpha=0.05, norm=False, char_weight=0.5     0.820259

# %%
report = pd.read_csv(DATA_DIR / 'member_a_nb_classification_report.csv', index_col=0)
matrix = pd.read_csv(DATA_DIR / 'member_a_nb_confusion_matrix.csv', index_col=0)
display(report)
matrix
# Out:
#               precision    recall  f1-score      support
# negative       0.746786  0.928423  0.827757  1439.000000
# neutral        0.856445  0.609451  0.712140  1439.000000
# positive       0.859043  0.897846  0.878016  1439.000000
# accuracy       0.811906  0.811906  0.811906     0.811906
# macro avg      0.820758  0.811906  0.805971  4317.000000
# weighted avg   0.820758  0.811906  0.805971  4317.000000
#                pred_negative  pred_neutral  pred_positive
# true_negative           1336            86             17
# true_neutral             367           877            195
# true_positive             86            61           1292
